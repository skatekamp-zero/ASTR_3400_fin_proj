# %% [markdown]
# Joshua please rename this to the project name

# %% [markdown]
# 1

# %%
# import packages
import astropy.io.fits
import os,sys,time
import numpy as np
from astropy.io import fits
import matplotlib.pyplot as plt
import warnings
from astropy.table import Table
warnings.filterwarnings("ignore")
from astropy import constants as const
from astropy import units as u
import matplotlib

matplotlib.rcParams['text.usetex'] = True
matplotlib.rcParams['font.size'] = 14

# %% [markdown]
# 2

# %%
# SDSS DR19Q
path_to_dr19q = ''
DR19_cat = fits.getdata(path_to_dr19q+'DR19Q_prop-v6_1_3.fits', 1)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [5], line 3
#       1 # SDSS DR19Q
#       2 path_to_dr19q = ''
# ----> 3 DR19_cat = fits.getdata(path_to_dr19q+'DR19Q_prop-v6_1_3.fits', 1)
#
# File ~/mambaforge/envs/py39/lib/python3.9/site-packages/astropy/io/fits/convenience.py:220, in getdata(filename, header, lower, upper, view, *args, **kwargs)
#     215 extver = kwargs.get("extver")
#     216 ext_given = not (
#     217     len(args) == 0 and ext is None and extname is None and extver is None
#     218 )
# --> 220 hdulist, extidx = _getext(filename, mode, *args, **kwargs)
#     221 try:
#     222     hdu = hdulist[extidx]
#
# File ~/mambaforge/envs/py39/lib/python3.9/site-packages/astropy/io/fits/convenience.py:1121, in _getext(filename, mode, ext, extname, extver, *args, **kwargs)
#    1118 elif extver and extname is None:
# ...

# %% [markdown]
# 3

# %%
# Checking if the files loaded in
print(path_to_dr16q)
print(os.path.exists(path_to_dr19q + 'DR19Q_prop-v6_1_3.fits'))
print(os.path.getsize(path_to_dr19q + 'DR19Q_prop-v6_1_3.fits')) 

print(DR16_cat.dtype.names)
print(DR19_cat.dtype.names)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [3], line 3
#       1 # Checking if the files loaded in
#       2 print(path_to_dr16q)
# ----> 3 print(os.path.exists(path_to_dr19q + 'DR19Q_prop-v6_1_3.fits'))
#       4 print(os.path.getsize(path_to_dr19q + 'DR19Q_prop-v6_1_3.fits'))
#       6 print(DR16_cat.dtype.names)
#
# NameError: name 'path_to_dr19q' is not defined

# %%
# DR 19 Server
# Select high-z massive BH quasars from DR19
z_cut = DR19_cat['Z_SYS'] > 5.0
# mass range
mass_cut = DR19_cat['LOGMBH'] > 5

# NaN check
# mass_finite = np.isfinite(DR19_cat['LOGMBH'])
# edd_finite = np.isfinite(DR19_cat['LOGLLEDD_RATIO'])

# creating an index   
indx = np.where(z_cut & mass_cut # &Mass_finite & edd_finite)
print(f"Objects selected: {len(indx[0])}")

# grab the selected objects
# adding data to sample
# sample = DR19_cat[indx]
            
print(f"Redshifts: {sample['Z_SYS'].min():.2f} - {sample['Z_SYS'].max():.2f}")
print(f"mass range: {sample['LOGMBH'].min():.2f} - {sample['LOGMBH'].max():.2f}")
print(f"ratio range: {sample['LOGLLEDD_RATIO'].min():.2f} - {sample['LOGLLEDD_RATIO'].max():.2f}")
# Out:
#   Cell In [4], line 13
#     print(f"Objects selected: {len(indx[0])}")
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# 1. calculate v
# 2. compare v
# 3. um
